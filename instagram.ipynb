# %%
import nltk
# -----------------------
# Used when first run
# nltk.download('wordnet')
# nltk.download('stopwords')
# -----------------------

import pandas as pd
import re
import string

from langdetect import detect
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import ComplementNB
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.feature_extraction.text import CountVectorizer

from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
stop_words = stopwords.words()

from collections import Counter

# %%
data = pd.read_csv("reviews.csv")
data.head()
# Out:
#                                reviewId       userName  \
# 0  c8c713be-146d-4f31-aaf6-2acc04aaafb1  A Google user
# 1  20bf512e-a675-4b96-afcb-9edb818dc727  A Google user
# 2  3ff788c5-9be2-4bd1-bd4f-da286c9c4770  A Google user
# 3  2662bbc4-fa1f-4f45-9019-11f68d7174f4  A Google user
# 4  680e9350-fcc2-41c7-89b1-523275d2c132  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0                                          Panbu 143      5              0
# 1                                             Update      5              0
# 2  You talk to anyone...🤌🏻💜... You can share your...      5              0
# 3            Madharchood aap sirf time pass karta he      3              0
# 4                                           Good app      5              0
#
#   reviewCreatedVersion                   at  replyContent  repliedAt  \
# 0       348.0.0.46.105  2024-09-13 15:54:11           NaN        NaN
# 1       278.0.0.22.117  2024-09-13 15:04:03           NaN        NaN
# 2       348.0.0.46.105  2024-09-13 15:03:52           NaN        NaN
# 3        288.1.0.22.66  2024-09-13 14:24:52           NaN        NaN
# 4       347.3.0.41.103  2024-09-13 13:56:33           NaN        NaN
#
#        appVersion
# 0  348.0.0.46.105
# 1  278.0.0.22.117
# 2  348.0.0.46.105
# 3   288.1.0.22.66
# 4  347.3.0.41.103

# %%
data = data[['userName','content', 'score','at']]
data
# Out:
#              userName                                            content  \
# 0       A Google user                                          Panbu 143
# 1       A Google user                                             Update
# 2       A Google user  You talk to anyone...🤌🏻💜... You can share your...
# 3       A Google user            Madharchood aap sirf time pass karta he
# 4       A Google user                                           Good app
# ...               ...                                                ...
# 319495  A Google user                      Very good app and very energy
# 319496  A Google user                                  It's is very nice
# 319497  A Google user             The best social media app ever created
# 319498  A Google user  The app is really good but there is a serious ...
# 319499  A Google user  Instagram is absolute rubbish nd political bia...
#
#         score                   at
# 0           5  2024-09-13 15:54:11
# 1           5  2024-09-13 15:04:03
# 2           5  2024-09-13 15:03:52
# 3           3  2024-09-13 14:24:52
# 4           5  2024-09-13 13:56:33
# ...       ...                  ...
# 319495      5  2024-06-08 04:19:36
# 319496      5  2024-06-08 04:17:25
# 319497      5  2024-06-08 04:16:56
# 319498      1  2024-06-08 04:16:49
# 319499      1  2024-06-08 04:16:11
#
# [319500 rows x 4 columns]

# %%
data.rename(columns={'content' : 'text'}, inplace=True)
data.rename(columns={'score' : 'sentiment'},inplace=True)

# %%
def remove_numbers(text):
    if isinstance(text, str):
        return ''.join(char for char in text if not char.isdigit())
    else:
        return text

def remove_character(text):
    if isinstance(text, str):  # checks if a string value exists
        text = text.lower()  # converting to lowercase
        text = re.sub('https?://\S+|www\.\S+', '', text)  # removing URL links
        text = re.sub(r"\b\d+\b", "", text)  # removing number
        text = re.sub('<.*?>+', '', text)  # removing special characters
        text = re.sub('[%s]' % re.escape(string.punctuation), '', text)  # punctuations
        text = re.sub('\n', '', text)
        text = re.sub('[’“”…]', '', text)
        return text
    else:
        return text

def remove_emoji(text):
    if isinstance(text, str):
        emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F700-\U0001F77F"  # alchemical symbols
                           u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                           u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                           u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                           u"\U0001FA00-\U0001FA6F"  # Chess Symbols
                           u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                           u"\U00002702-\U000027B0"  # Dingbats
                           u"\U000024C2-\U0001F251" 
                           "]+", flags=re.UNICODE)
        return emoji_pattern.sub(r'', text)
    else:
        return text


def remove_short_form(text):
    if isinstance(text, str):
        # removing short form:
        text = re.sub("isn't", 'is not', text)
        text = re.sub("he's", 'he is', text)
        text = re.sub("wasn't", 'was not', text)
        text = re.sub("there's", 'there is', text)
        text = re.sub("couldn't", 'could not', text)
        text = re.sub("won't", 'will not', text)
        text = re.sub("they're", 'they are', text)
        text = re.sub("she's", 'she is', text)
        text = re.sub("There's", 'there is', text)
        text = re.sub("wouldn't", 'would not', text)
        text = re.sub("haven't", 'have not', text)
        text = re.sub("That's", 'That is', text)
        text = re.sub("you've", 'you have', text)
        text = re.sub("He's", 'He is', text)
        text = re.sub("what's", 'what is', text)
        text = re.sub("weren't", 'were not', text)
        text = re.sub("we're", 'we are', text)
        text = re.sub("hasn't", 'has not', text)
        text = re.sub("you'd", 'you would', text)
        text = re.sub("shouldn't", 'should not', text)
        text = re.sub("let's", 'let us', text)
        text = re.sub("they've", 'they have', text)
        text = re.sub("You'll", 'You will', text)
        text = re.sub("i'm", 'i am', text)
        text = re.sub("we've", 'we have', text)
        text = re.sub("it's", 'it is', text)
        text = re.sub("don't", 'do not', text)
        text = re.sub("that´s", 'that is', text)
        text = re.sub("I´m", 'I am', text)
        text = re.sub("it’s", 'it is', text)
        text = re.sub("she´s", 'she is', text)
        text = re.sub("he’s'", 'he is', text)
        text = re.sub('I’m', 'I am', text)
        text = re.sub('I’d', 'I did', text)
        text = re.sub("he’s'", 'he is', text)
        text = re.sub('there’s','there is',text)
        return text
    else:
        return text
    
def remove_multiple_space(text):
    if isinstance(text, str):
        text = text.strip()
        text = re.sub(r'\s+', ' ', text)
        return text
    else:
        return text


def detect_english(text):
    try:
        return detect(text) == 'en'
    except Exception as e:
        print(f"Error detecting language: {e} - {text}")
        return False
    
cnt = Counter()
FREQWORDS = set([w for (w, wc) in cnt.most_common(10)])
def remove_freqwords(text):
    return " ".join([word for word in str(text).split() if word not in FREQWORDS])
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\S'
# <>:10: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\User\AppData\Local\Temp\ipykernel_21048\3245297276.py:10: SyntaxWarning: invalid escape sequence '\S'
#   text = re.sub('https?://\S+|www\.\S+', '', text)  # removing URL links

# %%
# remove number
data['text'] = data['text'].apply(remove_numbers)
data.to_csv('dataset_cleaned_2.csv', index=False)

# %%
# remove character
data = pd.read_csv('dataset/dataset_cleaned_2.csv')
data['text'] = data['text'].apply(remove_character)
data.to_csv('dataset/dataset_cleaned_3.csv', index=False)

# %%
# remove emoji
data = pd.read_csv('dataset/dataset_cleaned_3.csv')
data['text'] = data['text'].apply(remove_emoji)
data.to_csv('dataset/dataset_cleaned_4.csv', index=False)

# %%
# remove short form
data = pd.read_csv('dataset/dataset_cleaned_4.csv')
data['text'] = data['text'].apply(remove_short_form)
data.to_csv('dataset/dataset_cleaned_5.csv', index=False)

# %%
# remove multiple space
data = pd.read_csv('dataset/dataset_cleaned_5.csv')
data['text'] = data['text'].apply(remove_multiple_space)
data.to_csv('dataset/dataset_cleaned_6.csv', index=False)

# %%
# remove empty record and duplicate data
data = pd.read_csv('dataset/dataset_cleaned_6.csv')
data.drop_duplicates(inplace=True)
data.dropna(inplace=True)
data.to_csv('dataset/dataset_cleaned_7.csv', index=False)

# %%
# remove record non-english
data = pd.read_csv('dataset/dataset_cleaned_7.csv')
data['is_english'] = data['text'].apply(detect_english)
data = data[data['is_english']]
data = data.drop(columns=['is_english'])
data.to_csv('dataset/dataset_cleaned_8.csv', index=False)
# Out:
# Error detecting language: No features in text. - eᴡᴡᴇ ᴡᴇʀᴇ ᴇ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ••
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ↪↘↙↪↪↗↗↗
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ɪ ᴛʜɪɴᴋ ᴛʜɪs ɪs ᴛʜᴇ ʙᴇsᴛ ᴀᴘᴘ
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ရဿကက
# Error detecting language: No features in text. - လူတိုင်းမှာနှလုံးသားပါကြပါတယ်။သို့ပေမယ့်လူတိုင်းရင်ထဲမှာအကြင်နာတရားမရှိနေပါဘူး။ချစ်တယ်ဆိုတာလူတိုင်းအသုံးပြုနေကြပါတယ်။သစ္စာရှိရှိချစ်တာနဲ့သစ္စာမရှိရင်ခွင်တကာကိုခိုလုံဖို့စိတ်ရှိတဲ့သူပဲကွာသွားတာပါ။တကယ်တော့အချိန်တန်ရင်ကိုယ့်အဆင့်ကိုယ်သိက္ခာဘာလည်းဆိုတာကိုယ်ကိုတိုင်တောင်မသိနိုင်လောက်အောင်ကိုအောက်တန်းစားစိတ်နဲ့ပြုံးပြဖြဲပြနေတာတွေရှက်ရမှန်းတောင်မသိနိုင်လောက်အောင်ပဲချစ်ရတာလားဟင်ဟွန့်stupid singel mother
# Error detecting language: No features in text. - ɪɪɪ
# Error detecting language: No features in text. - ᴇᴋ ʟᴀᴅᴋɪ ʀᴇᴩʟy ɴᴀʜɪɴ ᴅᴇᴛɪ ᴋᴀɪᴀ ʜᴀɪ ɪɴᴛᴀɢʀᴀᴍ
# Error detecting language: No features in text. - សួរស្តី
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - €
# Error detecting language: No features in text. - නියමයි
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ⃣⃣
# Error detecting language: No features in text. - ᴠᴊɢ
# Error detecting language: No features in text. - ™
# Error detecting language: No features in text. - တတတတ​​​ေ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ғᴀʟᴛᴜ ᴀᴘᴘ ᴋᴇᴜ ʀᴇᴘʟʏ ᴅᴀɪɴᴀ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ⃟ᴠͥɪͣᴘͫ⃝iss ⃝
# Error detecting language: No features in text. - follow me on my ˚∧∧ —̳͟͞͞ •‿• —̳͟͞͞ —̳͟͞͞ —̳͟͞͞ —̳͟͞͞ —̳͟͞͞ ˚ ´
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - °°
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - €¥
# Error detecting language: No features in text. - ʰʰᵍᵍ
# Error detecting language: No features in text. - ´
# Error detecting language: No features in text. - sᴀʟᴀ ᴇɪsᴍᴇ ᴛᴏ ᴀᴇᴋʙʜɪ ʟᴅᴋɪ ɴʜɪ ᴘᴛᴛɪ ʜᴇ ʙᴇᴋᴀʀ ᴀᴇᴘ ʜᴇ ʏᴇᴛᴏ
# Error detecting language: No features in text. - ᴍᴜᴊʜᴇ ᴀᴩɴᴇ ᴀᴄᴄᴏᴜɴᴛ ᴩᴀʀ ᴏʟʟᴏᴡᴇʀ ᴄʜᴀʜɪyᴇ
# Error detecting language: No features in text. - ବହୁତ ଭଲ ଇନ୍ଷ୍ଟଗ୍ରାମ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ସୁପର
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ¿
# Error detecting language: No features in text. - ᴛᴀ ʙɪᴇɴ sʜɪᴅᴀ ʟᴀ ᴀᴘᴘ ᵘᵛᵘ
# Error detecting language: No features in text. - ପପୁ
# Error detecting language: No features in text. - €€
# Error detecting language: No features in text. - ℕ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ℎ
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ¶∆¢¥€
# Error detecting language: No features in text. - ℕ
# Error detecting language: No features in text. - ⃣⃣⃣⃣ ᚑ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚⌚
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ∇∇∇
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ℕ
# Error detecting language: No features in text. - ¡
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ॐ ॐ ॐ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ©©©©©©©©©©⁉⁉⁉‼‼⁉⁉⁉⁉⁉⁉⁉‼⁉
# Error detecting language: No features in text. - ≧≦
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴍʏ ᴅʀᴇᴀᴍ ᴇᴅɪᴛɪɴɢ ᴜᴄᴄᴇ ɪɴᴛᴀɢʀᴀᴍ ᴇᴅɪᴛɪɴɢ ᴢᴏɴᴇ ɪᴅ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ₹
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ₹
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - មិចញុមដើនឡូតអត់បានចឹង
# Error detecting language: No features in text. - ᏸ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴜᴩᴇʀ ᴊʜ ɢᴜᴅɢ ᴋʜᴜᴊᴛᴇᴏ ᴏᴇ ᴇᴋᴏᴛʀɪᴋᴀʀᴏɴ ʟᴏʀᴇɴ ᴋʜᴀᴅᴜ ᴜ ᴊɪᴛᴇɪʟᴇɴ ɪʀᴜᴋᴋᴀᴍᴀᴀᴛᴛᴀᴀʀɢᴀʟ ᴋʜᴇʟᴄʜʜɪʟᴀᴍ ᴊᴀɢᴀᴅɪʜᴄʜᴀɴᴅʀᴀ ᴏʀᴅʜᴇᴋᴇʀᴏ ᴅ ɢᴋ ᴏɪᴀʀᴛɪ ɪᴅᴇɴᴛɪy ᴏʀᴅʜᴏʜɪᴋᴋʜɪᴛᴏ ɪyᴀᴋᴋᴜɴᴀʀᴜᴅᴀɴ ʟᴇᴋʜᴀɢᴜʟᴀ ᴀɴᴋᴀ ᴋᴀʜᴀᴄʜɪᴄʜ ᴏʀᴛʜᴇᴅᴜᴋᴋᴀᴀɴ ᴋɴɪᴛᴛɪɴɢ ʜʜʜʜʜɢᴅᴜᴇ ʜᴏᴍᴇᴛᴏᴡɴ ɪɴᴛᴇʀᴠɪᴇᴡɪɴɢ ᴛᴇʀʀy yᴇᴇ ᴡᴩ ᴀʟʟ ɴʙᴄ ᴋʜᴀʟɪᴅ ᴊʙ ᴄʀᴜɴᴄʜ ᴏᴜᴛɪɴɢ ᴏᴛɪᴛʜɪ ᴩᴜʀᴛɪʀ ᴩᴀɪɴ ᴩᴀᴋᴀᴋʀɪyᴀ ᴩᴀᴋᴄʜᴇ ᴏᴜᴋʜ ᴩʀᴇᴅɪᴩᴏᴇᴅ ᴏᴜɢʜᴛ ᴏᴜᴛɢᴏɪɴɢ ᴏᴛʜ ɪɴɪɢʜᴛɪɴɢ ʟᴇᴋʜʙᴏ ɪᴅᴋ ʜᴀᴄʜᴏ ᴋɪᴄʜʜᴜᴛᴇᴏᴩᴇɴᴀʟᴛy ʟᴀᴋᴋʜɪʀ ʟᴀᴋᴋʜɪᴩᴜᴊᴏʀ ᴋʀɪʜɴᴏᴩʀᴏᴀᴅ ᴡɪᴋᴀᴀᴩᴀᴜɴ ᴋʀɴ ɴɢᴋ ᴋʜʙ ᴋɢ ᴊʜ ᴋɢ ᴊʜ ɪɢ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ԅ⁠⁠ ͒⁠ ⁠۝ ͒⁠ ⁠⁠ᕤ→⁠⁠°⁠ ⁠۝ ⁠°⁠⁠
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - °
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ⁠⁠⁠⁠⁠⁠⁠⁠
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴀᴡᴇᴏᴍᴇ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ⏰⏰⏰⏰⏰⏱⏰⏰
# Error detecting language: No features in text. - ‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ɢᴏᴏᴅ
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - በርከቲ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ¿
# Error detecting language: No features in text. - ដើម្បីទំនាក់ទំនងសង្គម និងកំសាន្ដ ។
# Error detecting language: No features in text. - ᴠɪʀᴀʟ ʀᴇᴇʟs ɴɪᴛɪɴxᴇᴅɪᴛx ғᴏʟʟᴏᴡ ᴋᴀʀᴅᴏ
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - lᴏᴠᴇ ᴀᴘᴘ
# Error detecting language: No features in text. - ɴᴀʀᴜᴛᴏ ᴀɴɪᴍᴇ
# Error detecting language: No features in text. - በበዘዘፈዘኀ ወወዘወወወወወ ፣በፈፈፈ ፈፈ ፈፈፈፈ ፈፈፈጸፈፈፈፈፈፈፈወበ ዘ ዘ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ℎ
# Error detecting language: No features in text. - မင်္ဂလာပါ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ᴛʜɪs ɪs ᴀᴍᴀᴢɪɴɢ ᴀᴘᴘ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴹᴿ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‿
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ɟǝ
# Error detecting language: No features in text. - ℙ
# Error detecting language: No features in text. - ᴀᴍᴀᴢɪɴɢ ɪᴛ ɢɪᴠᴇ ᴍᴏʀᴇ ɪɴsᴘɪʀᴀᴛɪᴏɴ ᴀʙᴏᴜᴛ ʟɪғᴇ
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ɢᴏᴏᴅ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ℎ ℎ ℎ ℎ ℎ
# Error detecting language: No features in text. - ÿ
# Error detecting language: No features in text. - ବଢିୟା ଆପ୍ ଇନ୍ଷ୍ଟଗ୍ରାମy
# Error detecting language: No features in text. - °•°•
# Error detecting language: No features in text. - ᴱⁿᵗᵉʳᵗᵃⁱⁿᵐᵉⁿᵗ ᶠᵘˡˡ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‼
# Error detecting language: No features in text. - ᴬᵃʳᵃᵛ ᵏᵘᵐᵃʳ
# Error detecting language: No features in text. - iᴛs ᴀɴ ᴀᴍᴀᴢɪɴɢ ᴀᴘᴘ ɪ ᴄᴀɴᴛ ᴅᴇғɪɴᴇ ɪᴛ ʙᴜᴛ ᴜ ᴄᴀɴ ᴜsᴇ ᴛʜɪs ᴛʜᴇɴ ᴜ ᴄᴀɴ ᴜɴᴅᴇʀsᴛᴀɴᴅ ᴡʜʏ ɪ ᴄᴀɴᴛ ᴅᴇғɪɴᴇ ɪᴛ
# Error detecting language: No features in text. - စးျ၌ၿႎံၿႎံယယ
# Error detecting language: No features in text. - ₹
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ြဖ​ေြပပ​ေ​ေဖဖ​ေ​ေဖ​ေပပပပayzzadazzaadဇဇဖ​ေပ္​
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - jdudhfufhfuurଋଣୃନଡୃଘେଢେନଗୃଘୃଧଗଳଜଡଛଢଜଗଚଧଗଜୂଗଗୂଗଜୁଗଧଚବଚଡଡଧୂଡନୂଡଝଡଦଚଧଚଡଧଧୂଛନଧଛଚଧଧଚନଛରଛରଛଧଛଛଧଛଧଧଚଛଵଦଚଢୃଧଡଝୂଢୂଫଦଦଭଧଦଵଦଦଵଥଵଛଢଥଘଛଢଯଣଛଢେଭଥଣଝଣରଭଥଵୟଛଷଯଵନଵଯଵଜଣୟଛଣୟେଷଦଣଙଢୟଵଧହଢଝଵୟଣଝଭୟଭଜଢଦକରଡୈଦଢଯଘଜଙୟେଭୟଣଛଭୟଣଜଙଥେଷଥଣଜଦଙଦଣଦଙଛନଢଥଵଜଘନଗଝତଘଯଘଜଚଷୟଥୟଡଦଦ୍ଦଡଧଡଧଡଧଡଥଢୟଯଣଛଙଯଣଥଣଥଙ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - නින්ද යන්න සුපිරි
# Error detecting language: No features in text. - — ° °
# Error detecting language: No features in text. - ℐ
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴘᴏ ʏʀʀ ᴄᴏᴏʟ ʏʀ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‌‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ¤
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ₹
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍
# Error detecting language: No features in text. - በጤማ አስፈላጊና በቀላል የሚተገበር ነወ ነገር ግነ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼઼
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ସୋପୋଟ
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - •ᴗ•
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ⅓
# Error detecting language: No features in text. - ʘ⁠‿⁠ʘ
# Error detecting language: No features in text. - ᵉʳʸ ᵍᵒᵒᵈ ᵃᵖᵖ ʷⁱᵗʰ ᴵⁿˢᵗᵃᵍʳᵃᵐ
# Error detecting language: No features in text. - ተበዱ
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ౕ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ူ
# Error detecting language: No features in text. - ⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴛʜɪs ᴀᴘᴘ ɪs ɢᴏᴏᴅ
# Error detecting language: No features in text. - ⁠⁠⁠⁠⁠⁠⁠⁠
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴀᴅᴀᏼᴏ ᥫ᭡
# Error detecting language: No features in text. - om‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴵᵈᵏ ʷʰʸ ᶦ ᶜᵃⁿᵗ ᵘˢᵉ ᵗʰᵉ ᴵⁿˢᵗᵃᵍʳᵃᵐ ᵃⁿʸᵐᵒʳᵉ ʷʰᵉⁿᵉᵛᵉʳ ᶦ ᵗʳᶦᵉ ᵗᵒ ᵘˢᵉ ᶦᵗ ᶦ ʲˢ ᶜᵃⁿᵗ
# Error detecting language: No features in text. - ɪᴛs ɢᴏᴏᴅ ᴀᴀᴘ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - හවසට වවැලිගම වල
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ʟᴏᴠᴇ ᴍᴇ ɪɢ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ͟͟͞͞
# Error detecting language: No features in text. - ₹
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍‍‍‍‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ඖඩිඅංබේඅංඒබතපේඨතතද
# Error detecting language: No features in text. - ⅞
# Error detecting language: No features in text. - ᴏᴋ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‿
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ɴɪᴄᴇ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ©
# Error detecting language: No features in text. - ዬነኘ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - አኣዩኴካኣኣእዌኲ
# Error detecting language: No features in text. - ʀᴀɢᴜʟ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ≧≦´ᴗ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ss we wlllbml bb bn⁠⁠o⁠⁠o⁠⁠o⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠o⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠o⁠⁠⁠⁠⁠⁠⁠⁠o⁠⁠o⁠⁠⁠o⁠⁠o
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ⌚
# Error detecting language: No features in text. - sᴇᴇɴ ᴘᴏʟɪ sᴀɴᴀᴍ
# Error detecting language: No features in text. - ʙᴀᴅ ᴏᴄɪᴀʟ ᴍᴇᴅɪᴀ ᴀᴩᴩ ᴅᴀᴛᴀ ᴇʀʀᴏʀ ʀᴇᴇʟ ʟᴏᴀᴅɪɴɢ ᴩʀᴏʙʟᴇᴍ ᴠᴇʀy ʙᴀᴅ
# Error detecting language: No features in text. - ®®©©®©
# Error detecting language: No features in text. - ℍ
# Error detecting language: No features in text. - ‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ହଜିଗଜଝଟଜ୍ଞ ଗଘ୍ନଭଃଫଂହ ଜଗଜହଃହଃ hnnnnhh ବିବି ବଭ ହବ ଉଃ ଜ୍ଞ ହଁ ଜୟ ଇଂନୁ ଇ ଇ ଇ ଉଁ ଉ ଉ ଇ ଇ ଇ ଇଞ୍ଜନ
# Error detecting language: No features in text. - ᴠᴇʀy ᴀᴍᴀᴢɪɴɢ ᴀᴩᴩ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‿
# Error detecting language: No features in text. - ⁠⁠
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ɴɪᴄᴇ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - mʀ᭄ᴀʀᴀɴ࿐
# Error detecting language: No features in text. - ɪsᴍᴀ ʙᴀɴᴅɪ sᴀ ʙᴀᴛ ᴋɪ ᴊᴀᴛɪ ʜᴀ
# Error detecting language: No features in text. - ɪɴsᴛɢʀᴀᴍ ᴍᴇ ʜɪɢʜʟɪɢʜᴛ ʟᴀɢᴀɴᴇ ᴋᴀ ᴏᴘᴛᴏsʜᴀɴ ɴᴀʜɪ ᴅᴀᴛᴀ ʜᴀɪ
# Error detecting language: No features in text. - ⁠⁠⁠
# Error detecting language: No features in text. - qr ଡାକାୟ ସେ ଫ
# Error detecting language: No features in text. - §
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ʙᴇsᴛ sᴏᴄɪᴀʟ ᴍᴇᴅɪᴀ ᴀᴘᴘ
# Error detecting language: No features in text. - ស្អាត
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍
# Error detecting language: No features in text. - ဒီအပ္ကအရမ္းသံုးလိုေကာင္းတယ္အဖက္ေတြလည္းမိုက္တယ္အရမ္းႀကိဳက္တယ္
# Error detecting language: No features in text. - ସସହି ରବବାକୁ ଢ ତମ ଼ବଡ଼ ଜିନିଷ ଡାକି ଗୋଂଦଷଡ ଜନନେ ଡାକି ପଲ ଜଯଜଯକାର ସସପେଣ୍ଡ ଚଲକର ତଟ ସସକ୍ବା
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - °
# Error detecting language: No features in text. - bᴀᴅ ʙᴀᴅ ʙᴀᴅ ᴀᴘᴘ ғᴏʀ ɢɪʀʟs
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍
# Error detecting language: No features in text. - ɴɪᴄᴇ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ଡଗହ ହଟ ଦ କସଟିରେ ଼
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - instagram ଗୁଟେ ବାଳ ଭଳିଆ app ଟା ବାଳ ଝିଅ ଗୋଟେ ବି ନାଇ ପଟକେ
# Error detecting language: No features in text. - ᴍʏ ғᴠʀᴛ ᴀᴘᴘ ᴀɴᴅ ᴍʏ ғᴇᴇʟɪɴɢs ᴜɴᴅᴇʀsᴛᴀɴᴅɪɴɢ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ℴ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‌‌‌‌‌
# Error detecting language: No features in text. - ᴏᴋ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ⁠⁠⁠⁠⁠ m ⁠⁠⁠⁠⁠
# Error detecting language: No features in text. - √√
# Error detecting language: No features in text. - ͢⃟≛⃝ ⃝
# Error detecting language: No features in text. - pin කර නොගන්නා clips පැයකට පසු ඉබේම නැ rති වී යයි v
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ɪ ʟᴏᴠᴇ ɪɴᴛᴀɢʀʀᴀᴍ
# Error detecting language: No features in text. - ᴍᴀsᴛᴀᴘᴘ
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ⁿⁿⁿⁿ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ታመነ አመንሲስ
# Error detecting language: No features in text. - သူဇာ
# Error detecting language: No features in text. - ≧≦
# Error detecting language: No features in text. - p ‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ₹
# Error detecting language: No features in text. - ᴜᴩᴇʀ ᴀᴩᴩ
# Error detecting language: No features in text. - ℋ ℴ ℐ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ⁠ʘ⁠ᴗ⁠ʘ⁠⁠
# Error detecting language: No features in text. - ₹
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - vᴇʀʏ ɴɪᴄᴇ ᴀᴘᴘ
# Error detecting language: No features in text. - nice ବହୁତ ସୁନ୍ଦର୍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ↗
# Error detecting language: No features in text. - ℎ ℎ ℎ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‼‼
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ່ ່ ່
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - sፀ።ፀከከከኳጨጨሰቿቿ፥ቷዠ፣ተ፣
# Error detecting language: No features in text. - ₩
# Error detecting language: No features in text. - ؟؟؟
# Error detecting language: No features in text. - တကယ်ကောင်းတဲ့ အက်ပ် ပါပဲ တော်လေးသုံးရအဆင်ပြေပီး ချစ်ဖို့ကောင်းတယ် ပုံတေလဲ တင်လို့ရတော့ အဆင်ပြေတာပေါ့
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - º º
# Error detecting language: No features in text. - ⁠‑⁠x
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‹••›´∇
# Error detecting language: No features in text. - ጌልረልጋጎ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ɴɪᴄᴇ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - አአአ በባአ
# Error detecting language: No features in text. - ଭଲ
# Error detecting language: No features in text. - ᴿᶜᴮ ᭄
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ₹
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴠᴇʀʏ ɢᴏᴏᴅ ᴀᴘᴘ
# Error detecting language: No features in text. - ••
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ଘ ᐛ ଓ´ ∫¯¯ ∫´∨ ˘ ˘
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ʜᴀɴᴅsᴏᴍᴇ ᴀᴘᴘ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‌‌‌‌‌‌‌‌ ‌‌‌‌‌‌
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ˢᵘᵖᵉʳ
# Error detecting language: No features in text. - ⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ରତିକାନ୍ତ ମହାପାତ୍ର
# Error detecting language: No features in text. - ‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ⃪⃪ ⃪⃪ ⃪⃪⃪ ⃪⃪⃪ ⃪⃪ ⃪⃪⃪
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ចូលចិត្ត
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ⌓
# Error detecting language: No features in text. - သုံးကောင်တယ်ef
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ଶିବ ସର୍ଥି ଫ୍ରୋଞ୍ ପୁସୂର୍
# Error detecting language: No features in text. - ɪ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ℯℴ ℴ ℯ ℴ ℴℴℯ ℯℯ ℯ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - မြန်လေးပါရှင့်
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‼
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ₹
# Error detecting language: No features in text. - →
# Error detecting language: No features in text. - ‼
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴛǫ ғᴏʀ ɪɴsᴛᴀɢʀᴀᴍ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‼‼‼‼‼‼‼‼‼
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - dᴏɴᴛ ᴜsᴇ ᴛʜɪs ᴀᴘᴘ ᴛʜɪs ᴀᴘᴘ ɪs ᴅᴇsɪʀᴠᴇ ʏᴏᴜʀ ғᴜᴛᴜʀᴇ
# Error detecting language: No features in text. - ɪʟᴏᴠᴇ ʏᴏᴜ ᴍʏ ᴍᴇᴍʙᴇʀs
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - បុ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴀʟᴡᴀy ᴠᴇʀy ɢᴏᴏᴅ ᴇᴍᴏᴛɪᴏɴ ʟᴏᴠᴇʟy ᴠɪᴅᴇᴏ ᴅᴏᴡɴʟᴏᴀᴅ ᴀᴄᴄᴇᴩᴛᴇᴅ ᴇᴠᴇʀyᴛʜɪɴɢ ᴜᴩᴇʀ ᴠᴇʀy ɢᴏᴏᴅ
# Error detecting language: No features in text. - ͡ ͡ ͡
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍
# Error detecting language: No features in text. - mᴀsᴛ ᴀᴀᴘ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ؟
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ବୀରୀରୂର
# Error detecting language: No features in text. - ̷̿̿
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ∫¯¯
# Error detecting language: No features in text. - ଭେରୀ
# Error detecting language: No features in text. - ကျေးဇူး
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ©™
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ɢᴏᴏᴅ
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ʟᴏᴠᴇ ʏᴏᴜ ɪɴsᴛᴀɢʀᴀᴍ
# Error detecting language: No features in text. - †††††††
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ®
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - °•°
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ᴠᴇʀʏ ɴɪᴄᴇ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴄʜɪɴɴᴀᴩʀᴀᴊ
# Error detecting language: No features in text. - ⏱
# Error detecting language: No features in text. - ℎℎℎℎℎℎℎℎℎℎℎℎ
# Error detecting language: No features in text. - ℱℴℴ ℊ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ppueotoloowoo uoz xz x ≧∇≦≧∇≦≧∇≦≧∇≦≧∇≦´∀≧∇≦´∀≧∇≦∀´∀≧∇≦´∀≧∇≦´∀´∀´∀≧∇≦≧∇≦≧∇≦≧∇≦≧∇≦≧∇≦≧∇≦≧∇≦´∀´∀≧∇≦´∀´∀≧∇≦∀≧∇≦ o o o oo
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - iiiwfiwics⁠⁠o⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠o⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠‍‍‍‍ pia
# Error detecting language: No features in text. - ɴɪᴄᴇ
# Error detecting language: No features in text. - ରାମେଶ
# Error detecting language: No features in text. - ༺༻
# Error detecting language: No features in text. - ¿
# Error detecting language: No features in text. - មុខម្ហូប​ ភេសជ្ជៈ និងប្រូម៉ូសិនរបស់ផ្ទះបុកល្ហុងខ្មែរ មាននៅទីនេះណាបងប្អូនម៉ូយៗ
# Error detecting language: No features in text. - ଭଲ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ℎ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴠᴇʀʏ ʙᴀᴅ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‿
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ⌚
# Error detecting language: No features in text. - ᴋʏᴀ ɢʜᴀᴛɪʏᴀ ᴀᴀᴘ ʜᴀɪ ᴀʟᴀ ᴇᴋ ʙʜɪ ʟᴀᴅᴋɪ ᴇᴛ ɴᴀʜɪ ʜᴏ ʀʜɪ ᴏʀ ɴᴀ ʜɪ ʀᴇᴘʟʏ ᴋʀ ʀʜɪ ʜᴀɪ ᴅᴏɴᴛ ɪɴᴛᴀʟʟ ᴛʜɪ ᴀᴘᴘ
# Error detecting language: No features in text. - ᴠᴀʀᴇ ɴɪᴄᴇ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‼
# Error detecting language: No features in text. - ɢᴏᴏᴅ
# Error detecting language: No features in text. - ɪ ᴍ ᴀʟᴡᴀʏs ᴜsᴇ ɪɴᴛᴀɢʀᴀᴍ
# Error detecting language: No features in text. - ‿
# Error detecting language: No features in text. - ଭଲ ଆପ୍ପଟେ ଆୟେ
# Error detecting language: No features in text. - ⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‼‼
# Error detecting language: No features in text. - g ⁠⁠o ⁠⁠o⁠⁠⁠⁠⁠ hug⁠⁠o ⁠⁠⁠⁠o⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠ ⁠⁠
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ⁦⁩⁦⁩⁦⁩⁦
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ɢօօ
# Error detecting language: No features in text. - ℎℎℎℎℎℎℎℎℎℎ
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ខ ។ សរុបសរុប ជម្រាបសួរជម្រាបសួរបាន សរសេរសរសេរ ។ សរុប មោកៗ កកកមម តាម
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ₹
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ᴊᴇɴɴʏ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍⏺
# Error detecting language: No features in text. - ̷̷̷̷̿̿̿̿̿̿̿̿
# Error detecting language: No features in text. - ⏰⏲⏲
# Error detecting language: No features in text. - •ᴗ•
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ÷
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ⅝
# Error detecting language: No features in text. - ‼
# Error detecting language: No features in text. - sᴋ᭄sᴀʙɪʀᴮᴼˢˢ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - so nice aap ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ପ୍ରିୟା କୁମାରୀ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ɴɪᴄᴇ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ɪɴsᴛᴀɢʀᴀᴍ is ᴀ ɢᴏᴏᴅ ᴀᴘᴘ ᴀᴍᴀᴢɪɴɢ ʙᴜᴛ ᴏɴᴇ ᴛʜɪɴɢ ᴀʟsᴏ hurt me ᴛʜᴀᴛ ɪs ᴛʜɪs ᴀᴘᴘ ɪs ᴛᴏᴏ ʀᴇsᴘᴏɴᴅʟᴀɢᴇ ɪ ᴀᴍ ᴀɴɢᴇʀ ɪɴ ᴛʜɪs ᴛɪᴍᴇ ғɪx ᴛʜɪs ᴘʀᴏʙɪʟᴇ ᴀɴᴅ ᴀᴅᴅ ᴀ ᴛʜɪɴɢ ᴛʜᴀᴛ ɪ ᴄᴀɴ ᴍᴏᴠᴇ ɪɴsᴀᴛᴀ ɪɴ sᴅ ᴄᴀʀᴅ ᴛʜᴀɴᴋᴜ ᴘʟᴇᴀsᴇ ʜᴇʟᴘ ᴍᴇ
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ƙɛƴᗩ ghᗩƭɩƴᗩ ᗩᑭᑭ hᗩɩ ɛƙ ᗷhɩ ᒪᗩᗪƙɩ ᖇɛᑭᒪƴ ᑎᗩhɩ ƙᗩᖇƭɩ ᗪoᑎƭ ɩᑎƭᗩᒪᒪ ƭhɩ ᗩᑭᑭ
# Error detecting language: No features in text. - ℴ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴺᵒ ˡᵃᵗᵉˢᵗ ⁿᵉʷˢ ᴼⁿ ʸᵒᵘʳ ⁱⁿˢᵗᵃᵍʳᵃᵐ ᵃⁿᵈ ⁱᵗ ⁱˢ ᵇᵒʳⁱⁿᵍ
# Error detecting language: No features in text. - ‍‼
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‼
# Error detecting language: No features in text. - ₹
# Error detecting language: No features in text. - a‍‍‍‍‍‍‍a
# Error detecting language: No features in text. - ‍‍‍‍‍‍⃣⃣⃣⃣⃣⃣⃣‍‍‍cool
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴍʏ ʟɪғᴇ
# Error detecting language: No features in text. - ᴍʏ ᴀᴄᴄ ɪ ᴛɪʟʟ ɴᴏᴛ ᴜᴘᴅᴀᴛᴇᴅ ᴛʀʏ ᴛᴏ ʜᴇʟᴘ ᴍᴇ ɪɴᴛᴀɢʀᴀᴍ
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ඔක්කොටම
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ဖူး
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ℕ
# Error detecting language: No features in text. - សុជាតា
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ᴀᴍᴇᴢɪɴɢ ᴡᴀᴡ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ⁠⁠⁠⁠⁠d⁠⁠⁠⁠o⁠⁠ ⁠⁠d
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‌‌‌
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ½
# Error detecting language: No features in text. - aᴡᴇsᴏᴍᴇ
# Error detecting language: No features in text. - ɢʀᴇᴀʀ
# Error detecting language: No features in text. - ɴᴇᴘᴀʟɪ
# Error detecting language: No features in text. - ‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ɪᴛs ᴀ ᴠᴇʀʏ ɢᴏᴏᴅ ᴀᴘᴘʟɪᴄᴀᴛɪᴏɴ ᴀɴᴅ ᴀʟsᴏ ᴍʏ ɢᴏ ᴛᴏ ᴀᴘᴘ ᴡʜᴇʀᴇ ɪ ᴄᴏɴɴᴇᴄᴛ ᴡɪᴛʜ ᴍʏ ғʀɪᴇɴᴅs ᴡᴇ ᴄᴀɴ ᴀʟsᴏ ᴍᴀᴋᴇ ᴀ sᴇᴘʀᴀᴛᴇ ᴀʟʙᴜᴍ ᴡɪᴛʜ ᴏᴜʀ ʜᴏᴍɪᴇs
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - sᴏ ᴄᴏᴏʟ
# Error detecting language: No features in text. - ៀបប
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ₩ • •
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ʜᴀ
# Error detecting language: No features in text. - ⁠⁠⁠
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‿
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ˢᵘᵖᵉʳ
# Error detecting language: No features in text. - ⏰
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ¶℅ ¶ € ¶ ¡ ¶¶ ¶¶℅
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ᴜᴩᴇʀʙ
# Error detecting language: No features in text. - ᴋɪ
# Error detecting language: No features in text. - ɪᴛ ᴠᴇʀʏ ɢᴏᴏᴅ
# Error detecting language: No features in text. - ∀•ᴗ••ᴗ••ᴗ•
# Error detecting language: No features in text. - ᴹᴿ°᭄࿐
# Error detecting language: No features in text. - ͢⃟≛⃝ ⃝
# Error detecting language: No features in text. - ʙᴀʜᴜᴛ ᴀᴀᴄʜᴀ ᴀᴀᴘ ʜᴀɪ ʙᴜᴛ ʏᴇ ᴀᴀᴘ ᴀᴀʙ sʜᴀᴀᴅɪ ᴄᴏᴍ ʙᴀɴ ɢᴀʏᴀ ʜᴀɪ ᴏʀʀ ᴍᴜᴊᴇ ᴋᴇsᴇ sᴇ ᴋᴏɪ ᴍᴀᴛʟʙ ɴʜɪ ʜᴀɪ ʙᴀss ᴍᴇʀᴇ ɪᴅ ᴘᴇʀ ʙʟᴜᴇ ᴛɪᴄᴋ ʟᴀɢ ᴊᴀʏᴇ ᴀɴᴅ ᴛʜᴀɴᴋ ᴜᴜᴜ ɪɴsᴛᴀɢʀᴀᴍ ғᴀᴍɪʟʏ
# Error detecting language: No features in text. - ̷̿̿
# Error detecting language: No features in text. - ᴛʜᴇ ᴀᴘᴘ
# Error detecting language: No features in text. - ℕ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ଭାଇ ଭଲ app ନୁହ କେହି ଗୋଟେ ଝିଅ ପଟୁ ନାହାନ୍ତି
# Error detecting language: No features in text. - ‍‍‍‍‍
# Error detecting language: No features in text. - mᴇᴇᴛs ɴᴇᴡ ᴘᴇᴏᴘʟᴇ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ⅝⅝
# Error detecting language: No features in text. - ⅚
# Error detecting language: No features in text. - za acᕦ ͡° ͜ʖ ͡°ᕤᴥᴥ ∫ଘ ᐛ ଓ´ ∫ ∫ᴥᕦ ͡° ͜ʖ ͡°ᕤ

# %%
# remove stop word:
data = pd.read_csv('dataset/dataset_cleaned_8.csv')
data['text'] = data['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
data.to_csv('dataset/dataset_cleaned_9.csv', index=False)

# %%
# remove empty record and duplicate data
data = pd.read_csv('dataset/dataset_cleaned_9.csv')
data.drop_duplicates(inplace=True)
data.dropna(inplace=True)
data.to_csv('dataset/dataset_cleaned_9.csv', index=False)

# %%
# Remove the most frequent words:
data = pd.read_csv('dataset/dataset_cleaned_9.csv')
data["text"] = data["text"].apply(lambda text: remove_freqwords(text))
data.to_csv('dataset/dataset_cleaned_10.csv', index=False)

# %%
# Change Rating
data = pd.read_csv('dataset/dataset_cleaned_10.csv')
data['sentiment'] = [0 if each in (1, 2, 3) else 1 for each in data.sentiment]
data.to_csv('dataset/dataset_cleaned_11.csv', index=False)

# %% [markdown]
# tokenization

# %%
# Change Rating
data = pd.read_csv('dataset/dataset_cleaned_10.csv')
data['sentiment'] = [0 if each in (1, 2, 3) else 1 for each in data.sentiment]
data.to_csv('dataset/dataset_cleaned_11.csv', index=False)

# %% [markdown]
# model evaluation

# %%
#split dataset
X_train, X_test, y_train, y_test = train_test_split(text_counts, data['sentiment'], test_size=0.20, random_state=30)

model = ComplementNB()
model.fit(X_train, y_train)
predicted = model.predict(X_test)
accuracy_score = metrics.accuracy_score(predicted, y_test)
print('ComplementNB model accuracy is', str('{:04.2f}'.format(accuracy_score*100))+'%')
print('------------------------------------------------')

print('Confusion Matrix:')
print(pd.DataFrame(confusion_matrix(y_test, predicted)))
print('------------------------------------------------')
print('Classification Report:')
print(classification_report(y_test, predicted))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 #split dataset
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(text_counts, data['sentiment'], test_size=0.20, random_state=30)
#       4 model = ComplementNB()
#       5 model.fit(X_train, y_train)
#
# NameError: name 'text_counts' is not defined

# %% [markdown]
# visualization

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# Confusion Matrix Visualization
cf_matrix = confusion_matrix(y_test, predicted)

group_names = ['TP','TN','FP','FN']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2,2)

sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Greens')

plt.title('Confusion Matrix')
plt.show()

# %%
# Accuracy Visualization
accuracy_score = metrics.accuracy_score(predicted, y_test)
plt.figure(figsize=(10, 2))
plt.bar(['Accuracy'], [accuracy_score], color=['green'])
plt.ylim(0, 1)
plt.title('Model Accuracy')
plt.show()
print('ComplementNB model accuracy is', str('{:04.2f}'.format(accuracy_score*100))+'%')

# %%
# Word Cloud Visualization
def plot_wordcloud(text, title):
    wordcloud = WordCloud(width=800, height=400,background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(title)
    plt.show()

# Sentiment Positive
positive_text = ' '.join(data[data['sentiment'] == 1]['text'])
plot_wordcloud(positive_text, 'Word Cloud for Positive Sentiment')

# Sentiment Positive
negatif_text = ' '.join(data[data['sentiment'] == 0]['text'])
plot_wordcloud(negatif_text, 'Word Cloud for Negative Sentiment')

# %%
# Visualization Sentiment
data['sentiment'] = data['sentiment'].replace({1: 'Positif', 0: 'Negatif'})
sentiment_counts = data['sentiment'].value_counts()

# Visualization with pie charts
plt.figure(figsize=(6, 6))
plt.pie(sentiment_counts, labels=sentiment_counts.index,autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightskyblue'])
plt.title('Distribution of Sentiments')
plt.show()
