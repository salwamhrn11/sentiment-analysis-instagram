# %%
import pandas as pd
from google_play_scraper import app, Sort, reviews #buat scraping app
from pprint import pprint #printing data structures
import pymongo
from pymongo import MongoClient #storing di mongodb
import datetime as dt
from tzlocal import get_localzone
import random
import time

# %%
#setup mongodb
client = MongoClient(host='localhost', port=27017)
app_db = client['app_db']
info_collection = app_db['info_collection']
review_collection = app_db['review_collection']

# %%
rvws, token = reviews (
    'com.instagram.android',
    lang='en',
    country='us',
    sort=Sort.NEWEST,
    count=1000000
)

# %%
rvws
# Out:
# [{'reviewId': 'c8c713be-146d-4f31-aaf6-2acc04aaafb1',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Panbu 143',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '348.0.0.46.105',
#   'at': datetime.datetime(2024, 9, 13, 15, 54, 11),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '348.0.0.46.105'},
#  {'reviewId': '20bf512e-a675-4b96-afcb-9edb818dc727',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Update',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '278.0.0.22.117',
#   'at': datetime.datetime(2024, 9, 13, 15, 4, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '278.0.0.22.117'},
# ...

# %%
len(rvws)
# Out:
# 319500

# %%
reviews_df = pd.DataFrame(rvws)
reviews_df.to_csv('reviews.csv',index=None, header=True)

# %%
reviews_df
# Out:
#                                     reviewId       userName  \
# 0       c8c713be-146d-4f31-aaf6-2acc04aaafb1  A Google user
# 1       20bf512e-a675-4b96-afcb-9edb818dc727  A Google user
# 2       3ff788c5-9be2-4bd1-bd4f-da286c9c4770  A Google user
# 3       2662bbc4-fa1f-4f45-9019-11f68d7174f4  A Google user
# 4       680e9350-fcc2-41c7-89b1-523275d2c132  A Google user
# ...                                      ...            ...
# 319495  171d32f9-6523-4619-9bbb-efcb9e659ddf  A Google user
# 319496  4eb6a786-9be0-4f4d-82db-8376e1a5b7d2  A Google user
# 319497  3191f3e9-d5ea-41d8-8ee5-515cd5709cb9  A Google user
# 319498  e9f0b098-280b-4a1a-92e0-660c9a2b4aa5  A Google user
# 319499  e815e26b-88bc-4312-be9d-3fe8143a08ac  A Google user
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/EGemoI2N...
# 1       https://play-lh.googleusercontent.com/EGemoI2N...
# 2       https://play-lh.googleusercontent.com/EGemoI2N...
# ...
